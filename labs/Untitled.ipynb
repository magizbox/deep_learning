# %%
import numpy as np

# %%
np.var([1, 2, 3])
# Out:
# 0.66666666666666663

# %%
for i in np.arange(0, 5, 0.02):
    print i, np.std([1, 2, 3, i])
# Out:
# 0.0 1.11803398875
# 0.02 1.11133928213
# 0.04 1.10467189699
# 0.06 1.09803233104
# 0.08 1.09142109197
# 0.1 1.08483869769
# 0.12 1.07828567643
# 0.14 1.07176256699
# 0.16 1.06526991885
# 0.18 1.05880829237
# 0.2 1.05237825899
# 0.22 1.04598040135
# 0.24 1.03961531347
# 0.26 1.03328360095
# 0.28 1.02698588111
# 0.3 1.02072278313
# 0.32 1.01449494824
# 0.34 1.00830302985
# 0.36 1.00214769371
# 0.38 0.996029618034
# 0.4 0.989949493661
# 0.42 0.983908024157
# 0.44 0.977905925946
# 0.46 0.971943928424
# 0.48 0.966022774059
# 0.5 0.960143218484
# 0.52 0.954306030579
# 0.54 0.948511992544
# 0.56 0.942761899951
# 0.58 0.937056561793
# 0.6 0.93139680051
# 0.62 0.925783452002
# 0.64 0.920217365626
# 0.66 0.914699404176
# 0.68 0.909230443837
# 0.7 0.903811374126
# 0.72 0.898443097809
# 0.74 0.893126530789
# 0.76 0.887862601983
# 0.78 0.882652253155
# 0.8 0.877496438739
# 0.82 0.872396125622
# 0.84 0.867352292901
# 0.86 0.862365931609
# 0.88 0.857438044409
# 0.9 0.852569645249
# ...

# %%
np.sqrt(2.0/ 3)
# Out:
# 0.81649658092772603

# %%
# Out:
# array([ 0. ,  0.5,  1. ,  1.5])

# %%
np.power(0.9025 - 0.675, 2)
# Out:
# 0.051756249999999969

# %%
import numpy as np

E = 0.675 
X = 90.25 / 100
S = 0.065

print "%.2f" % ((X - E) / S)
# Out:
# 3.50

# %%
(X - E) / S
# Out:
# 3.4999999999999987

# %%
import math

# %%
math.sqrt(3 * 3 + 4 * 4)
# Out:
# 5.0
